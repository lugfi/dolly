# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("http://dollyfiuba.com/db_dolly.txt?dskjdks")
docentes = data.doc.unique()
data
# Out:
#                    doc   mat    cuat         tstamp asistencia  \
# 0               Garcia  6109  1Q2018  1533839977934          5
# 1            Travesaro  6109  1Q2018  1533839977936          5
# 2               Pastor  6109  1Q2018  1533839977937          5
# 3                 Piva  6203  1Q2018  1533840118491          5
# 4           A Designar  6203  1Q2018  1533840118494          5
# 5            Di Luozzo  6203  1Q2018  1533840118496          5
# 6             Irigoyen  7645  1Q2017  1533840138397          5
# 7     Eugenio Russmann  7645  1Q2017  1533840138401          5
# 8                Tello  7645  1Q2017  1533840138405          5
# 9                Garea  8201  1Q2018  1533840141558          5
# 10              Veiras  8201  1Q2018  1533840141559          5
# 11              Duplaa  8201  1Q2018  1533840141560          5
# 12            Vazquez   8201  1Q2018  1533840141561          4
# 13           Fernandez  8201  1Q2018  1533840141563          4
# ...

# %%
data.columns.tolist()
# Out:
# ['doc',
#  'mat',
#  'cuat',
#  'tstamp',
#  'asistencia',
#  'cumple_horarios',
#  'buen_trato',
#  'calse_organizada',
#  'claridad',
#  'fomenta_participacion',
#  'panorama_amplio',
#  'acepta_critica',
#  'responde_mails',
#  'comentarios']

# %%
x=data[((data.mat == 6108) | (data.mat == 8102) ) & (data.doc == 'Boggi')].loc[:,'asistencia':'responde_mails']
m = x.mean(numeric_only=True)
m
# Out:
# cumple_horarios          3.000000
# buen_trato               4.500000
# calse_organizada         3.666667
# claridad                 4.000000
# fomenta_participacion    4.000000
# panorama_amplio          3.666667
# acepta_critica           4.333333
# responde_mails           2.833333
# dtype: float64

# %%
x.std(numeric_only=True)
# Out:
# cumple_horarios          1.414214
# buen_trato               0.836660
# calse_organizada         1.505545
# claridad                 0.894427
# fomenta_participacion    1.095445
# panorama_amplio          1.632993
# acepta_critica           0.816497
# responde_mails           1.329160
# dtype: float64

# %%
m.mean()
# Out:
# 3.7499999999999996
